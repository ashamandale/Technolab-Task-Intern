# %% [markdown]
# # Advanced Uses of SHAP Values

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv('FIFA 2018 Statistics.csv')
data
# Out:
#            Date          Team      Opponent  Goal Scored  Ball Possession %  \
# 0    14-06-2018        Russia  Saudi Arabia            5                 40
# 1    14-06-2018  Saudi Arabia        Russia            0                 60
# 2    15-06-2018         Egypt       Uruguay            0                 43
# 3    15-06-2018       Uruguay         Egypt            1                 57
# 4    15-06-2018       Morocco          Iran            0                 64
# ..          ...           ...           ...          ...                ...
# 123  11-07-2018       England       Croatia            1                 46
# 124  14-07-2018       Belgium       England            2                 43
# 125  14-07-2018       England       Belgium            0                 57
# 126  15-07-2018        France       Croatia            4                 39
# 127  15-07-2018       Croatia        France            2                 61
#
#      Attempts  On-Target  Off-Target  Blocked  Corners  ...  Yellow Card  \
# 0          13          7           3        3        6  ...            0
# 1           6          0           3        3        2  ...            0
# 2           8          3           3        2        0  ...            2
# 3          14          4           6        4        5  ...            0
# 4          13          3           6        4        5  ...            1
# ..        ...        ...         ...      ...      ...  ...          ...
# 123        11          1           6        4        4  ...            1
# 124        12          4           3        5        4  ...            1
# 125        15          5           7        3        5  ...            2
# 126         8          6           1        1        2  ...            2
# 127        15          3           8        4        6  ...            1
#
#      Yellow & Red  Red  Man of the Match  1st Goal         Round  PSO  \
# 0               0    0               Yes      12.0   Group Stage   No
# 1               0    0                No       NaN   Group Stage   No
# 2               0    0                No       NaN   Group Stage   No
# 3               0    0               Yes      89.0   Group Stage   No
# 4               0    0                No       NaN   Group Stage   No
# ..            ...  ...               ...       ...           ...  ...
# 123             0    0                No       5.0  Semi- Finals   No
# 124             0    0               Yes       4.0     3rd Place   No
# 125             0    0                No       NaN     3rd Place   No
# 126             0    0               Yes      18.0         Final   No
# 127             0    0                No      28.0         Final   No
#
#      Goals in PSO  Own goals  Own goal Time
# 0               0        NaN            NaN
# 1               0        NaN            NaN
# 2               0        NaN            NaN
# 3               0        NaN            NaN
# 4               0        1.0           90.0
# ..            ...        ...            ...
# 123             0        NaN            NaN
# 124             0        NaN            NaN
# 125             0        NaN            NaN
# 126             0        1.0           18.0
# 127             0        NaN            NaN
#
# [128 rows x 27 columns]

# %%
y = (data['Man of the Match'] == "Yes")
y
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 123    False
# 124     True
# 125    False
# 126     True
# 127    False
# Name: Man of the Match, Length: 128, dtype: bool

# %%
feature_names = [i for i in data.columns if data[i].dtype in [np.int64, np.int64]]
feature_names
# Out:
# ['Goal Scored',
#  'Ball Possession %',
#  'Attempts',
#  'On-Target',
#  'Off-Target',
#  'Blocked',
#  'Corners',
#  'Offsides',
#  'Free Kicks',
#  'Saves',
#  'Pass Accuracy %',
#  'Passes',
#  'Distance Covered (Kms)',
#  'Fouls Committed',
#  'Yellow Card',
#  'Yellow & Red',
#  'Red',
#  'Goals in PSO']

# %%
X = data[feature_names]
X
# Out:
#      Goal Scored  Ball Possession %  Attempts  On-Target  Off-Target  Blocked  \
# 0              5                 40        13          7           3        3
# 1              0                 60         6          0           3        3
# 2              0                 43         8          3           3        2
# 3              1                 57        14          4           6        4
# 4              0                 64        13          3           6        4
# ..           ...                ...       ...        ...         ...      ...
# 123            1                 46        11          1           6        4
# 124            2                 43        12          4           3        5
# 125            0                 57        15          5           7        3
# 126            4                 39         8          6           1        1
# 127            2                 61        15          3           8        4
#
#      Corners  Offsides  Free Kicks  Saves  Pass Accuracy %  Passes  \
# 0          6         3          11      0               78     306
# 1          2         1          25      2               86     511
# 2          0         1           7      3               78     395
# 3          5         1          13      3               86     589
# 4          5         0          14      2               86     433
# ..       ...       ...         ...    ...              ...     ...
# 123        4         3          24      5               79     479
# 124        4         1           5      5               88     510
# 125        5         0          12      2               92     698
# 126        2         1          14      1               75     271
# 127        6         1          15      3               83     547
#
#      Distance Covered (Kms)  Fouls Committed  Yellow Card  Yellow & Red  Red  \
# 0                       118               22            0             0    0
# 1                       105               10            0             0    0
# 2                       112               12            2             0    0
# 3                       111                6            0             0    0
# 4                       101               22            1             0    0
# ..                      ...              ...          ...           ...  ...
# 123                     148               14            1             0    0
# 124                     108               11            1             0    0
# 125                     110                5            2             0    0
# 126                      99               14            2             0    0
# 127                     100               13            1             0    0
#
#      Goals in PSO
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 123             0
# 124             0
# 125             0
# 126             0
# 127             0
#
# [128 rows x 18 columns]

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

# %%
my_model = RandomForestClassifier(random_state=0).fit(train_X, train_y)
my_model
# Out:
# RandomForestClassifier(random_state=0)

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in /home/ihack-pc/anaconda3/lib/python3.8/site-packages (0.39.0)
# Requirement already satisfied: slicer==0.0.7 in /home/ihack-pc/anaconda3/lib/python3.8/site-packages (from shap) (0.0.7)
# Requirement already satisfied: pandas in /home/ihack-pc/.local/lib/python3.8/site-packages (from shap) (1.3.2)
# Requirement already satisfied: tqdm>4.25.0 in /home/ihack-pc/anaconda3/lib/python3.8/site-packages (from shap) (4.59.0)
# Requirement already satisfied: scipy in /home/ihack-pc/.local/lib/python3.8/site-packages (from shap) (1.7.1)
# Requirement already satisfied: cloudpickle in /home/ihack-pc/anaconda3/lib/python3.8/site-packages (from shap) (1.6.0)
# Requirement already satisfied: numpy in /home/ihack-pc/.local/lib/python3.8/site-packages (from shap) (1.21.2)
# Requirement already satisfied: scikit-learn in /home/ihack-pc/.local/lib/python3.8/site-packages (from shap) (0.24.2)
# Requirement already satisfied: numba in /home/ihack-pc/anaconda3/lib/python3.8/site-packages (from shap) (0.53.1)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /home/ihack-pc/anaconda3/lib/python3.8/site-packages (from numba->shap) (0.36.0)
# Requirement already satisfied: setuptools in /home/ihack-pc/anaconda3/lib/python3.8/site-packages (from numba->shap) (52.0.0.post20210125)
# Requirement already satisfied: pytz>=2017.3 in /home/ihack-pc/anaconda3/lib/python3.8/site-packages (from pandas->shap) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ihack-pc/anaconda3/lib/python3.8/site-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/ihack-pc/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /home/ihack-pc/.local/lib/python3.8/site-packages (from scikit-learn->shap) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ihack-pc/.local/lib/python3.8/site-packages (from scikit-learn->shap) (2.2.0)

# %%
import shap
explainer = shap.TreeExplainer(my_model)
shap_values = explainer.shap_values(val_X)
shap.summary_plot(shap_values[1],val_X)
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/ihack-pc/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
